# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")
# Out:
# CUDA available: True
# GPU name: NVIDIA GeForce RTX 4050 Laptop GPU

# %%
# !nvidia-smi
# Out:
# Tue Dec  3 11:37:51 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P4              8W /   30W |       0MiB /   6141MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install opencv-python

# %%
# !pip install ultralytics

# %%
import os 
from ultralytics import YOLO

# %%
model = YOLO("yolov8s.pt") # This loads a new YOLOv8 model

# %%
results = model.train(data="yolov8_dataset.yaml", epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.39  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
model = YOLO("yolov8m.pt") # This loads a new YOLOv8 model

# %%
results = model.train(data="yolov8_dataset.yaml", epochs=100)
# Out:
# New https://pypi.org/project/ultralytics/8.3.40 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.39  Python-3.9.20 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...
